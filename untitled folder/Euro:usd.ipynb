# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
import matplotlib.pyplot as plt

# Step 1: Download and preprocess the data
ticker = 'EURUSD=X'
data = yf.download(ticker, start='2010-01-01', end='2024-05-20')
data = data[['Close']].copy()  # Ensure we are working with a copy
# Out:
# 2024-05-21 19:29:51.879904: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [*********************100%%**********************]  1 of 1 completed

# %%
# Step 2: Feature Engineering
# (Implement Elliott Wave and other features as needed)
data.loc[:, 'Return'] = data['Close'].pct_change()
data.dropna(inplace=True)

# %%
# Step 3: Data Preparation
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data['Close'].values.reshape(-1, 1))

sequence_length = 60
X, y = [], []
for i in range(sequence_length, len(data_scaled)):
    X.append(data_scaled[i-sequence_length:i])
    y.append(data_scaled[i, 0])
X, y = np.array(X), np.array(y)

# Step 4: Build LSTM Model
model = Sequential()
model.add(Input(shape=(X.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Step 5: Training and Evaluation
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - loss: 0.0832 - val_loss: 4.8355e-04
# Epoch 2/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - loss: 0.0042 - val_loss: 5.0150e-04
# Epoch 3/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0037 - val_loss: 3.6158e-04
# Epoch 4/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0034 - val_loss: 4.1466e-04
# Epoch 5/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0030 - val_loss: 3.9125e-04
# Epoch 6/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.0030 - val_loss: 3.6211e-04
# Epoch 7/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0028 - val_loss: 3.6479e-04
# Epoch 8/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0029 - val_loss: 5.1783e-04
# Epoch 9/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0027 - val_loss: 3.3879e-04
# Epoch 10/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.0028 - val_loss: 4.2476e-04
# Epoch 11/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0026 - val_loss: 3.9000e-04
# Epoch 12/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0024 - val_loss: 3.6478e-04
# Epoch 13/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0025 - val_loss: 3.5715e-04
# Epoch 14/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0023 - val_loss: 3.1303e-04
# Epoch 15/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0022 - val_loss: 2.7588e-04
# Epoch 16/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0023 - val_loss: 3.0017e-04
# Epoch 17/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0021 - val_loss: 2.7005e-04
# Epoch 18/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0019 - val_loss: 5.4318e-04
# Epoch 19/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0020 - val_loss: 2.6404e-04
# Epoch 20/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0018 - val_loss: 2.7151e-04
# Epoch 21/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0019 - val_loss: 2.9058e-04
# Epoch 22/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0018 - val_loss: 3.8640e-04
# Epoch 23/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0019 - val_loss: 2.4311e-04
# Epoch 24/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0018 - val_loss: 3.7600e-04
# Epoch 25/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0018 - val_loss: 3.7163e-04
# Epoch 26/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0016 - val_loss: 3.1411e-04
# Epoch 27/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0018 - val_loss: 2.8948e-04
# Epoch 28/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0016 - val_loss: 3.3085e-04
# Epoch 29/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0017 - val_loss: 3.4952e-04
# Epoch 30/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0015 - val_loss: 2.3238e-04
# Epoch 31/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0015 - val_loss: 2.2728e-04
# Epoch 32/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.0015 - val_loss: 2.1461e-04
# Epoch 33/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0014 - val_loss: 2.2970e-04
# Epoch 34/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0014 - val_loss: 2.8442e-04
# Epoch 35/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0014 - val_loss: 2.1749e-04
# Epoch 36/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0013 - val_loss: 2.3129e-04
# Epoch 37/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0014 - val_loss: 2.7332e-04
# Epoch 38/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0014 - val_loss: 2.2086e-04
# Epoch 39/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0012 - val_loss: 2.0221e-04
# Epoch 40/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0011 - val_loss: 2.2223e-04
# Epoch 41/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0011 - val_loss: 2.1254e-04
# Epoch 42/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0013 - val_loss: 2.3211e-04
# Epoch 43/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0012 - val_loss: 2.6380e-04
# Epoch 44/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0011 - val_loss: 2.8393e-04
# Epoch 45/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.0011 - val_loss: 2.1094e-04
# Epoch 46/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 9.7471e-04 - val_loss: 1.8251e-04
# Epoch 47/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 9.8959e-04 - val_loss: 1.8053e-04
# Epoch 48/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 9.4023e-04 - val_loss: 1.9993e-04
# Epoch 49/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 9.0809e-04 - val_loss: 2.2173e-04
# Epoch 50/50
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 9.2369e-04 - val_loss: 1.8430e-04

# %%
# Step 6: Prediction and Visualization
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step

# %%
# Correct the indices for plotting
train_data_len = split + sequence_length
test_data_index = data.index[train_data_len:train_data_len + len(predictions)]

plt.figure(figsize=(14,5))
plt.plot(data.index[sequence_length:], data['Close'][sequence_length:], color='blue', label='Actual Price')
plt.plot(test_data_index, predictions, color='red', label='Predicted Price')
plt.title('EUR/USD Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Assuming `predictions` and `y_test` are already defined
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_actual, predictions)
mae = mean_absolute_error(y_test_actual, predictions)
r2 = r2_score(y_test_actual, predictions)

print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.19994258914060656
# Mean Absolute Error: 0.4465096285579324
# R-squared: -87.20382399894066

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Convert the predicted and actual prices into binary classes (up or down)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Determine the direction of the price movement
y_test_direction = np.diff(y_test_actual, axis=0).reshape(-1)
predictions_direction = np.diff(predictions, axis=0).reshape(-1)

# Convert to binary classification: 1 for up, 0 for down
y_test_binary = (y_test_direction > 0).astype(int)
predictions_binary = (predictions_direction > 0).astype(int)

# Calculate confusion matrix
cm = confusion_matrix(y_test_binary, predictions_binary)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
disp.plot()

plt.title('Confusion Matrix of Price Direction Prediction')
plt.show()
